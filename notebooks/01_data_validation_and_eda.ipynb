# %% [markdown]
# # Karachi AQI Data Validation And EDA
#
# This notebook is the evaluator-facing entry point for Phase 3. It delegates to the reproducible EDA code in `src/aqi_predictor/analysis/eda.py` so the analysis can also run in CI or from a terminal without hidden notebook state.

# %%
from pathlib import Path
import sys

def find_project_root(start: Path) -> Path:
    for candidate in [start, *start.parents]:
        if (candidate / "pyproject.toml").exists() and (candidate / "src").exists():
            return candidate
    raise RuntimeError("Could not find repository root. Open this notebook from inside the 10Pearls_Shine project.")

ROOT = find_project_root(Path.cwd().resolve())
SRC = ROOT / "src"
if str(SRC) not in sys.path:
    sys.path.insert(0, str(SRC))

from aqi_predictor.analysis.eda import run_eda

summary = run_eda()
summary
